# %%
import pandas as pd
import numpy as np

submission=pd.read_csv("data/sample_submission.csv",index_col=0)
ans = pd.read_csv("./scheduler_leakyrelu_kfold_submission.csv")

# %%
ans.to_numpy()
# Out:
# array([[0.47680464, 0.43529162],
#        [0.59101808, 0.30046922],
#        [0.24678579, 0.24756041],
#        [0.23920389, 0.21684606],
#        [0.17153075, 0.18732612],
#        [0.38637981, 0.36058179],
#        [0.33028287, 0.3056291 ],
#        [0.15807319, 0.14939329],
#        [0.19661404, 0.18748394],
#        [0.16985796, 0.17173104],
#        [0.25948367, 0.26833913],
#        [0.20997521, 0.2163897 ],
#        [0.28617102, 0.29669029],
#        [0.14855143, 0.14887697],
#        [0.18317047, 0.18105385],
#        [0.28808823, 0.33410296],
#        [0.44192839, 0.40198618],
#        [0.22566052, 0.20862432],
#        [0.18924007, 0.18225953],
#        [0.56641519, 0.4893074 ],
#        [0.30526799, 0.30026278],
#        [0.67017853, 0.5803116 ],
#        [0.27191505, 0.25151721],
#        [0.31019053, 0.2955308 ],
#        [0.21163574, 0.22314176],
#        [0.24128744, 0.23041415],
#        [0.35553542, 0.32552761],
#        [0.28249636, 0.26638812],
# ...

# %%
submission.iloc[:,:] = ans.to_numpy()

# %%
submission.to_csv("ans_1.csv")

# %%
submission.to_csv("ans_1.csv")
